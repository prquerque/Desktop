# %% [markdown]
# <a href="https://colab.research.google.com/github/prquerque/Desktop/blob/master/Atividade2911.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clonar
# !git clone https://github.com/angsoz1952/api_toTodo.git
# Out:
# Cloning into 'api_toTodo'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 46 (delta 14), reused 40 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 11.05 KiB | 11.05 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# !cd api_toTodo
# !git remote add origin https://github.com/prquerque/api_toTodo.git
# !git branch -M main
# !git push -u origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git remote add origin https://github.com/SEU_USUARIO/api_toTodo.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# 1. Clona o repositório (você já fez)
# !git clone https://github.com/angsoz1952/api_toTodo.git
# %cd api_toTodo

# 2. Verifica em qual branch você está agora
# !git branch

# 3. Opção A – Renomear a branch atual (ex: de main para develop)
# !git branch -m main develop          # se a branch atual for "main"
# ou
# !git branch -m master develop        # se for "master"

# 3. Opção B – (RECOMENDADO) Criar e mudar para uma nova branch
# !git checkout -b develop             # cria e já entra na branch "develop"
# ou qualquer outro nome que quiser:
# !git checkout -b meu-nome-aqui

# 4. Verifica se deu certo
# !git branch

# 5. (Opcional) Conectar sua branch ao remote e enviar
# !git push -u origin develop
# Out:
# Cloning into 'api_toTodo'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 46 (delta 14), reused 40 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 11.05 KiB | 11.05 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/api_toTodo/api_toTodo
# * main
# fatal: A branch named 'develop' already exists.
# fatal: A branch named 'develop' already exists.
# * develop
# fatal: could not read Username for 'https://github.com': No such device or address
